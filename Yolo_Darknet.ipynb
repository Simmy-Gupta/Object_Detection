# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls '/content/drive/MyDrive/Object_Detection'
# Out:
# backup	   chart_yolov3_custom.png  darknet  yolo_custom_dataset.ipynb
# chart.png  custom_weight	    Images

# %%
#!unzip '/content/drive/MyDrive/Object_Detection/Images.zip' -d '/content/drive/MyDrive/Object_Detection'

# %%
#!git clone 'https://github.com/AlexeyAB/darknet.git' '/content/drive/MyDrive/Object_Detection/darknet'

# %%
# %cd /content/drive/MyDrive/Object_Detection/darknet
# Out:
# /content/drive/MyDrive/Object_Detection/darknet

# %%
# !ls
# Out:
# 3rdparty	DarknetConfig.cmake.in	json_mjpeg_streams.sh  scripts
# backup		darknet_images.py	LICENSE		       src
# build		darknet.py		Makefile	       vcpkg.json
# build.ps1	darknet_video.py	net_cam_v3.sh	       video_yolov3.sh
# cfg		data			net_cam_v4.sh	       video_yolov4.sh
# cmake		image_yolov3.sh		obj
# CMakeLists.txt	image_yolov4.sh		README.md
# darknet		include			results

# %%
# !make
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
#              ^~
# ...

# %%
# %cd /content/drive/MyDrive/Object_Detection
# Out:
# /content/drive/MyDrive/Object_Detection

# %%
# !python /content/drive/MyDrive/Object_Detection/Images/creating-files-data-and-name.py

# %%
# !python /content/drive/MyDrive/Object_Detection/Images/creating-train-and-test-txt-files.py

# %%
# !darknet/darknet
# Out:
# usage: darknet/darknet <function>

# %%
# !darknet/darknet detector train /content/drive/MyDrive/Object_Detection/Images/labelled_data.data /content/drive/MyDrive/Object_Detection/darknet/cfg/yolov3_custom.cfg /content/drive/MyDrive/Object_Detection/custom_weight/darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 65994, rewritten_bbox = 0.000000 %
#
#  6540: 0.192383, 0.039483 avg loss, 0.000100 rate, 1.812007 seconds, 52320 images, 0.296432 hours left
# Resizing, random_coef = 1.40
#
#  480 x 480
#  try to allocate additional workspace_size = 4.15 MB
#  CUDA allocate done!
# Loaded: 0.000069 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.883502), count: 1, class_loss = 0.000001, iou_loss = 0.023931, total_loss = 0.023932
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 65995, rewritten_bbox = 0.000000 %
# ...
